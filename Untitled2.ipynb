# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pylab as plt

# %%
from matplotlib.pylab import rcParams

# %%
rcParams['figure.figsize'] = 300,150

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%d-%b-%y')
data = pd.read_csv('Cleaner_data.csv',parse_dates=['Donation_Date'], index_col='Donation_Date',date_parser=dateparse)

# %%
data.sample(10)
# Out:
#                row ID  Financial_Year Branch_Code  Sequence_1  Sequence_2  \
# Donation_Date
# 2013-10-17      15117              14      BRC-01       92896     15117.0
# 2013-10-28      16725              14      BRC-01       94504     16725.0
# 2016-04-30     112054              16      BRC-01       33727     31384.0
# 2016-07-28     122561              17      BRC-01        4092      3637.0
# 2015-01-20      65418              15      BRC-01       22331     21099.0
# 2015-06-13      78981              15      BRC-01       35894     34662.0
# 2017-08-08     163633              18      BRC-01        5007      4219.0
# 2015-04-27      74533              15      BRC-01       31446     30214.0
# 2015-08-23      85982              16      BRC-01        7655      5311.0
# 2018-06-04     217177              18      BRC-02       24636     14954.0
#
#               Donation_type  Donor_Age Gender  Blood_Group_Code  Donor_Weight  \
# Donation_Date
# 2013-10-17                R       28.0      M                 3          65.0
# 2013-10-28                R       23.0      M                 5          60.0
# 2016-04-30                M       31.0      M                 3          70.0
# 2016-07-28                R       27.0      M                 5          80.0
# 2015-01-20                R       22.0      M                 1          80.0
# 2015-06-13                T       33.0      M                 1          67.0
# 2017-08-08                T       27.0      M                 4          63.0
# 2015-04-27                R       28.0      M                 7          90.0
# 2015-08-23                R       19.0      M                 5          95.0
# 2018-06-04                R       28.0      M                 5          72.0
#
#                Donor_Temperature  Donor_Pulse  Donor_Hemoglobin  \
# Donation_Date
# 2013-10-17                  37.0           72              14.0
# 2013-10-28                  37.0           72              13.0
# 2016-04-30                  37.0           72              14.0
# 2016-07-28                  37.0           72              13.0
# 2015-01-20                  37.0           72              13.0
# 2015-06-13                  37.0           76              14.0
# 2017-08-08                  37.0           72              14.0
# 2015-04-27                  37.0           72              13.0
# 2015-08-23                  37.0           78              13.0
# 2018-06-04                  37.0           72              13.0
#
#               Donor_Blood_Pressure  Test_1 C1  Test_2 C2 Test_3 Test_4
# Donation_Date
# 2013-10-17                  120/80   0.143  N   0.211  N      N      N
# 2013-10-28                  120/80   0.152  N   0.244  N      N      N
# 2016-04-30                  110/90   0.084  N   0.221  N      N      N
# 2016-07-28                  120/80   0.183  N   0.242  N      N      N
# 2015-01-20                  120/80   0.351  N   0.261  N      N      N
# 2015-06-13                  120/80   0.414  N   0.201  N      N      N
# 2017-08-08                  80/120   0.103  N   0.174  N      N      N
# 2015-04-27                  120/80   0.432  N   0.163  N      N      N
# 2015-08-23                  120/80   0.573  N   0.234  N      N      N
# 2018-06-04                  120/80   0.122  N   0.100  N      N      N

# %%
data[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\program files\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-c402bf503b75> in <module>
# ----> 1 data[1]
#
# d:\program files\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# d:\program files\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
data.head().next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5ffce9ba810e> in <module>
# ----> 1 data.head().next()
#
# d:\program files\python\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'next'
