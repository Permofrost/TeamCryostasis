# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(num=None, figsize=(80, 60), dpi=80, facecolor='w', edgecolor='k')

# %%
df = pd.read_csv('Cleaner_data.csv')

# %%
df.columns = ['row ID','Financial_Year','Branch_Code','Sequence_1','Sequence_2','Donation_type','Donor_Age','Donation_Date','Gender','Blood_Group_Code','Donor_Weight','Donor_Temperature','Donor_Pulse','Donor_Hemoglobin','Donor_Blood_Pressure','Test_1','C1','Test_2','C2','Test_3','Test_4']

# %%
df = df.dropna()

# %%
df['Date'] = pd.to_datetime(df.Donation_Date, format='%d-%b-%y')

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#             row ID  Financial_Year Branch_Code  Sequence_1  Sequence_2  \
# Date
# 2013-07-01       1              14      BRC-01         345         1.0
# 2013-07-01       2              14      BRC-01         346         2.0
# 2013-07-01       3              14      BRC-01         347         3.0
# 2013-07-01       4              14      BRC-01         348         4.0
# 2013-07-01       5              14      BRC-01         349         5.0
#
#            Donation_type  Donor_Age Donation_Date Gender  Blood_Group_Code  \
# Date
# 2013-07-01             R       24.0      1-Jul-13      M                 5
# 2013-07-01             R       33.0      1-Jul-13      M                 3
# 2013-07-01             R       28.0      1-Jul-13      M                 5
# 2013-07-01             R       20.0      1-Jul-13      M                 3
# 2013-07-01             T       22.0      1-Jul-13      M                 7
#
#             ...  Donor_Temperature  Donor_Pulse  Donor_Hemoglobin  \
# Date        ...
# 2013-07-01  ...               37.0           72              13.0
# 2013-07-01  ...               37.0           72              13.0
# 2013-07-01  ...               37.0           72              13.0
# 2013-07-01  ...               37.0           72              13.0
# 2013-07-01  ...               37.0           72              13.0
#
#             Donor_Blood_Pressure Test_1  C1 Test_2  C2 Test_3 Test_4
# Date
# 2013-07-01                120/80  0.121   N  0.224   N      R      N
# 2013-07-01                120/80  0.122   N  0.222   N      N      N
# 2013-07-01                120/80  0.123   N  0.221   N      N      N
# 2013-07-01                120/80  0.123   N  0.242   N      N      N
# 2013-07-01                120/80  0.124   N  0.243   N      N      N
#
# [5 rows x 21 columns]

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 25
fig_size[1] = 15
df.plot('Donation_Date', 'Donor_Age')

# %%
print("Current size:", fig_size)
# Out:
# Current size: [25, 15]

# %%
df['Donor_Age'].resample().mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-4067762a351f> in <module>
# ----> 1 df['Donor_Age'].resample().mean()
#
# TypeError: resample() missing 1 required positional argument: 'rule'

# %%
monthly_summary = pd.DataFrame()
monthly_summary['Donor_Age'] = df['Donor_Age'].resample('M').mean()
monthly_summary['Donor_Weight'] = df['Donor_Weight'].resample('M').mean()
monthly_summary['Blood_Group_Code'] = df['Blood_Group_Code'].resample('M').mean()
monthly_summary['Donor_Temperature'] = df['Donor_Temperature'].resample('M').mean()
monthly_summary['Donor_Pulse'] = df['Donor_Pulse'].resample('M').mean()
monthly_summary['Donor_Hemoglobin'] = df['Donor_Hemoglobin'].resample('M').mean()
monthly_summary['Test_1'] = df['Test_1'].resample('M').mean()
monthly_summary['Test_2'] = df['Test_2'].resample('M').mean()

# %%
monthly_summary = monthly_summary.truncate(before='2016-01-05', after='2017-06-05')

# %%
monthly_summary.head()
# Out:
#             Donor_Age  Donor_Weight  Blood_Group_Code  Donor_Temperature  \
# Date
# 2016-01-31  28.750469     73.369656          3.618129          37.000321
# 2016-02-29  28.934682     75.401719          3.669402          36.999609
# 2016-03-31  28.579593     72.719046          3.654156          37.000000
# 2016-04-30  28.846367     72.574519          3.614354          37.000000
# 2016-05-31  28.592782     73.809009          3.613385          37.000257
#
#             Donor_Pulse  Donor_Hemoglobin    Test_1     Test_2
# Date
# 2016-01-31    73.233044         13.034908  0.231897  63.113129
# 2016-02-29    72.491989         13.008597  0.617841  54.743598
# 2016-03-31    72.260961         13.034549  0.172371  64.980092
# 2016-04-30    72.359203         13.061298  0.164813  61.750550
# 2016-05-31    72.134620         13.030373  0.131451  69.675042

# %%
monthly_summary.plot()
