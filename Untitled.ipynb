# %%
import pandas as pd
import re

df = pd.read_csv('Clean_data.csv')
df.head()
# Out:
#    row ID  Financial_Year Branch_Code  Sequence_1  Sequence_2 Donation_type  \
# 0       1              14      BRC-01         345         1.0             R
# 1       2              14      BRC-01         346         2.0             R
# 2       3              14      BRC-01         347         3.0             R
# 3       4              14      BRC-01         348         4.0             R
# 4       5              14      BRC-01         349         5.0             T
#
#    Donor_Age Donation_Date Gender  Blood_Group_Code  ...  Donor_Temperature  \
# 0       24.0      1-Jul-13      M                 5  ...               37.0
# 1       33.0      1-Jul-13      M                 3  ...               37.0
# 2       28.0      1-Jul-13      M                 5  ...               37.0
# 3       20.0      1-Jul-13      M                 3  ...               37.0
# 4       22.0      1-Jul-13      M                 7  ...               37.0
#
# ...

# %%
cols = ['row ID', 'Financial_Year','Branch_Code', 'Sequence_1','Sequence_2', 'Donation_type',
        'Donor_Age','Gender','Donor_Weight',
        'Donor_Temperature', 'Donor_Pulse', 'Donor_Hemoglobin', 'Donor_Blood_Pressure',
        'Test_1','C1','Test_2','C2','Test_3','Test_4']
df.drop(cols,axis=1, inplace=True)
df.isnull().sum()
# Out:
# Donation_Date       0
# Blood_Group_Code    0
# dtype: int64

# %%
df = df.groupby('Donation_Date')
['Donation_Blood_Group'].sum().reset_index()
df.set_index('Donation_Date')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b8ff3aa36808> in <module>
# ----> 1 df = df.groupby('Donation_Date')
#       2 ['Donation_Blood_Group'].sum().reset_index()
#       3 df.set_index('Donation_Date')
#
# d:\program files\python\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     531             return self[attr]
#     532         if hasattr(self.obj, attr):
# --> 533             return self._make_wrapper(attr)
#     534
#     535         raise AttributeError("%r object has no attribute %r" %
#
# d:\program files\python\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     568                    "using the 'apply' method".format(kind, name,
#     569                                                      type(self).__name__))
# --> 570             raise AttributeError(msg)
#     571
# ...

# %%
df['26-jul-17':]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b6be5b3955e3> in <module>
# ----> 1 df['26-jul-17':]
#
# d:\program files\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906
#    2907         # Do we have a slicer (on rows)?
# -> 2908         indexer = convert_to_index_sliceable(self, key)
#    2909         if indexer is not None:
#    2910             return self._slice(indexer, axis=0)
#
# d:\program files\python\lib\site-packages\pandas\core\indexing.py in convert_to_index_sliceable(obj, key)
#    2454     idx = obj.index
#    2455     if isinstance(key, slice):
# -> 2456         return idx._convert_slice_indexer(key, kind='getitem')
#    2457
#    2458     elif isinstance(key, compat.string_types):
#
# d:\program files\python\lib\site-packages\pandas\core\indexes\base.py in _convert_slice_indexer(self, key, kind)
# ...
